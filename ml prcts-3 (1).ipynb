# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('8358__1.csv')

# %%
df
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# ...                    ...                                      ...
# 3505  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3506  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3507  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3508  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3509  AVweZioPIN2L1WUf4kR_              9563 Kings Charter Doctor B
#
#                           categories            city country  \
# 0                        Pizza Place            Bend      US
# ...

# %%
df.head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %%
df.shape
# Out:
# (3510, 21)

# %%
df.tail()
# Out:
#                         id                      address  \
# 3505  AVweYUZ0IN2L1WUf4Z9q                   305 Ash St
# 3506  AVweYUZ0IN2L1WUf4Z9q                   305 Ash St
# 3507  AVweZ5SbIN2L1WUf4nWU             4140 Carlisle Rd
# 3508  AVweZ5SbIN2L1WUf4nWU             4140 Carlisle Rd
# 3509  AVweZioPIN2L1WUf4kR_  9563 Kings Charter Doctor B
#
#                          categories            city country  \
# 3505              Bar and Gastropub  Jefferson City      US
# 3506              Bar and Gastropub  Jefferson City      US
# 3507  Restaurant,Italian Restaurant           Dover      US
# 3508  Restaurant,Italian Restaurant           Dover      US
# 3509                     Restaurant         Ashland      US
#
#                                                    keys   latitude  longitude  \
# 3505    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717 -92.161596
# 3506    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717 -92.161596
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510 entries, 0 to 3509
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3510 non-null   object
#  1   address             3510 non-null   object
#  2   categories          3510 non-null   object
#  3   city                3510 non-null   object
#  4   country             3510 non-null   object
#  5   keys                3510 non-null   object
#  6   latitude            3510 non-null   float64
#  7   longitude           3510 non-null   float64
#  8   menuPageURL         610 non-null    object
#  9   menus.amountMax     2948 non-null   float64
#  10  menus.amountMin     2948 non-null   float64
#  11  menus.currency      2951 non-null   object
#  12  menus.dateSeen      3510 non-null   object
#  13  menus.description   1526 non-null   object
#  14  menus.name          3510 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# address                  0
# categories               0
# city                     0
# country                  0
# keys                     0
# latitude                 0
# longitude                0
# menuPageURL           2900
# menus.amountMax        562
# menus.amountMin        562
# menus.currency         559
# menus.dateSeen           0
# menus.description     1984
# menus.name               0
# name                     0
# postalCode              26
# priceRangeCurrency    1953
# priceRangeMin         1953
# priceRangeMax         1953
# province                 0
# dtype: int64

# %%
missing_value_per = df.isnull().sum()/df.shape[0]*100
missing_value_per
# Out:
# id                     0.000000
# address                0.000000
# categories             0.000000
# city                   0.000000
# country                0.000000
# keys                   0.000000
# latitude               0.000000
# longitude              0.000000
# menuPageURL           82.621083
# menus.amountMax       16.011396
# menus.amountMin       16.011396
# menus.currency        15.925926
# menus.dateSeen         0.000000
# menus.description     56.524217
# menus.name             0.000000
# name                   0.000000
# postalCode             0.740741
# priceRangeCurrency    55.641026
# priceRangeMin         55.641026
# priceRangeMax         55.641026
# province               0.000000
# dtype: float64

# %%
missing_value_clm_gre_20 = missing_value_per[missing_value_per > 20].keys()
missing_value_clm_gre_20
# Out:
# Index(['menuPageURL', 'menus.description', 'priceRangeCurrency',
#        'priceRangeMin', 'priceRangeMax'],
#       dtype='object')

# %%
df2 = df.drop(columns = missing_value_clm_gre_20)
df2
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# ...                    ...                                      ...
# 3505  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3506  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3507  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3508  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3509  AVweZioPIN2L1WUf4kR_              9563 Kings Charter Doctor B
#
#                           categories            city country  \
# 0                        Pizza Place            Bend      US
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#df2_num=df_drop_clm.select_dtypes(include=['int64','float64'])  you correct my code......
#df2_num.head()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
df2.isnull().sum()
# Out:
# id                   0
# address              0
# categories           0
# city                 0
# country              0
# keys                 0
# latitude             0
# longitude            0
# menus.amountMax    562
# menus.amountMin    562
# menus.currency     559
# menus.dateSeen       0
# menus.name           0
# name                 0
# postalCode          26
# province             0
# dtype: int64

# %% [markdown]
# missing_num_var = [var fir var in df2.columns if df2[var].isnull().sum()>0]

# %%
missing_num_var = [var for var in df2.columns if df2[var].isnull().sum()>0]
missing_num_var
# Out:
# ['menus.amountMax', 'menus.amountMin', 'menus.currency', 'postalCode']

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2,2,i+1)

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df2[var],bins=20, kde_kws={'linewidth':5,'coler':'red'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13304/2997625945.py in <module>
#       3 for i, var in enumerate(missing_num_var):
#       4     plt.subplot(2,2,i+1)
# ----> 5     sns.distplot(df2[var],bins=20, kde_kws={'linewidth':5,'coler':'red'})
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2685     if kde:
#    2686         kde_color = kde_kws.pop("color", color)
# -> 2687         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#    2688         if kde_color != color:
#    2689             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
# ...

# %%
#plz, currect index no 81, i want a distplot for a know mean mode meadian, and i want remove out lyres,
#how we plot out lyres and plot boxplot
